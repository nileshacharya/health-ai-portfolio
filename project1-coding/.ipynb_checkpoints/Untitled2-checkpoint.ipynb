# %%
#Connection setup (run once at top of every notebook)
import psycopg2
import pandas as pd
import json
import sys
sys.path.append('/Users/nilesh/health-ai-portfolio/project1-coding')
from coding_engine import build_encounter_context

# Start with your richest encounter
context = build_encounter_context(
    '9917e9f0-753a-4673-da3f-ca0de161db03'
)
print(json.dumps(context, indent=2, default=str))
# Out:
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)
# {
#   "encounter": {
#     "encounter_id": "9917e9f0-753a-4673-da3f-ca0de161db03",
#     "patient_id": "9917e9f0-753a-4673-69f1-ca9c42b5669f",
#     "encounter_class": "IMP",
#     "encounter_type": "Hospital admission for isolation (procedure)",
#     "encounter_date": "2020-08-30",
#     "duration_hours": 336.9,
#     "reason": "Disease caused by severe acute respiratory syndrome coronavirus 2 (disorder)",
#     "patient_gender": "female",
#     "patient_age": 28
#   },
#   "conditions": {
#     "diagnoses": [
#       {
#         "code": "233604007",
#         "display": "Pneumonia (disorder)",
#         "status": "resolved"
#       },
#       {
#         "code": "389087006",
#         "display": "Hypoxemia (disorder)",
#         "status": "resolved"
#       },
#       {
#         "code": "132281000119108",
#         "display": "Acute deep venous thrombosis (disorder)",
#         "status": "resolved"
#       }
#     ],
#     "social_determinants": [
#       {
#         "code": "271825005",
#         "display": "Respiratory distress (finding)",
#         "status": "resolved"
#       }
#     ],
#     "total_conditions": 4,
#     "data_quality": {
#       "has_conditions": true,
#       "flag": null
#     }
#   },
#   "procedures": {
#     "clinical_procedures": [
#       {
#         "code": "371908008",
#         "display": "Oxygen administration by mask (procedure)",
#         "occurrence_count": 15
#       },
#       {
#         "code": "431182000",
#         "display": "Placing subject in prone position (procedure)",
#         "occurrence_count": 15
#       },
#       {
#         "code": "399208008",
#         "display": "Plain X-ray of chest (procedure)",
#         "occurrence_count": 1
#       }
#     ],
#     "administrative_procedures": [],
#     "total_procedures": 3,
#     "data_quality": {
#       "high_procedure_count": false,
#       "flag": null
#     }
#   },
#   "medications": {
#     "medications": [
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       }
#     ],
#     "count": 45,
#     "data_quality": {
#       "has_medications": true,
#       "flag": null
#     }
#   },
#   "observations": {
#     "observations": [
#       {
#         "display": "Respiratory rate",
#         "value": "12.274 /min",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Heart rate",
#         "value": "149.87 /min",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Oxygen saturation in Arterial blood",
#         "value": "78.03 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Body Weight",
#         "value": "77.8 kg",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Leukocytes [#/volume] in Blood by Automated count",
#         "value": "3.4189 10*3/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Erythrocytes [#/volume] in Blood by Automated count",
#         "value": "5.5694 10*6/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Hemoglobin [Mass/volume] in Blood",
#         "value": "11.552 g/dL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Hematocrit [Volume Fraction] of Blood by Automated count",
#         "value": "45.266 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "MCV [Entitic mean volume] in Red Blood Cells by Automated count",
#         "value": "89.755 fL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "MCH [Entitic mass] by Automated count",
#         "value": "28.311 pg",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "MCHC [Entitic Mass/volume] in Red Blood Cells by Automated count",
#         "value": "33.728 g/dL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Erythrocyte [DistWidth] in Blood by Automated count",
#         "value": "13.444 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Platelets [#/volume] in Blood by Automated count",
#         "value": "119.55 10*3/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Neutrophils/Leukocytes in Blood by Automated count",
#         "value": "26.288 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Lymphocytes/Leukocytes in Blood by Automated count",
#         "value": "21.513 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Monocytes/Leukocytes in Blood by Automated count",
#         "value": "12.75 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Eosinophils/Leukocytes in Blood by Automated count",
#         "value": "4.4726 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Basophils/Leukocytes in Blood by Automated count",
#         "value": "3.4109 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Neutrophils [#/volume] in Blood by Automated count",
#         "value": "3.7072 10*3/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Lymphocytes [#/volume] in Blood by Automated count",
#         "value": "1.0258 10*3/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Monocytes [#/volume] in Blood by Automated count",
#         "value": "0.878 10*3/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Eosinophils [#/volume] in Blood by Automated count",
#         "value": "0.42216 10*3/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Basophils [#/volume] in Blood by Automated count",
#         "value": "0.22518 10*3/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Glucose [Mass/volume] in Serum or Plasma",
#         "value": "80.8 mg/dL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Urea nitrogen [Mass/volume] in Serum or Plasma",
#         "value": "7.36 mg/dL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Creatinine [Mass/volume] in Serum or Plasma",
#         "value": "2.5724 mg/dL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Calcium [Mass/volume] in Serum or Plasma",
#         "value": "9.04 mg/dL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Sodium [Moles/volume] in Serum or Plasma",
#         "value": "139.04 mmol/L",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Potassium [Moles/volume] in Serum or Plasma",
#         "value": "4.29 mmol/L",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Body temperature",
#         "value": "41.588 Cel",
#         "date": "2020-08-30"
#       }
#     ],
#     "count": 30
#   },
#   "insurance": {
#     "insurer": "Anthem",
#     "total_cost": 29926.9,
#     "insurance_paid": 23943.9,
#     "patient_responsibility": 5983.0,
#     "requires_prior_auth": true
#   },
#   "metadata": {
#     "assembled_at": "2026-05-13T16:08:49.029216",
#     "encounter_id": "9917e9f0-753a-4673-da3f-ca0de161db03",
#     "data_quality_flags": []
#   }
# }
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)

# %%
#Connection setup (run once at top of every notebook)
import psycopg2
import pandas as pd
import json
import sys
sys.path.append('/Users/nilesh/health-ai-portfolio/project1-coding')
from coding_engine import build_encounter_context

# Start with your richest encounter
context = build_encounter_context(
    '9917e9f0-753a-4673-da3f-ca0de161db03'
)
print(json.dumps(context, indent=2, default=str))
# Out:
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)
# {
#   "encounter": {
#     "encounter_id": "9917e9f0-753a-4673-da3f-ca0de161db03",
#     "patient_id": "9917e9f0-753a-4673-69f1-ca9c42b5669f",
#     "encounter_class": "IMP",
#     "encounter_type": "Hospital admission for isolation (procedure)",
#     "encounter_date": "2020-08-30",
#     "duration_hours": 336.9,
#     "reason": "Disease caused by severe acute respiratory syndrome coronavirus 2 (disorder)",
#     "patient_gender": "female",
#     "patient_age": 28
#   },
#   "conditions": {
#     "diagnoses": [
#       {
#         "code": "233604007",
#         "display": "Pneumonia (disorder)",
#         "status": "resolved"
#       },
#       {
#         "code": "389087006",
#         "display": "Hypoxemia (disorder)",
#         "status": "resolved"
#       },
#       {
#         "code": "132281000119108",
#         "display": "Acute deep venous thrombosis (disorder)",
#         "status": "resolved"
#       }
#     ],
#     "social_determinants": [
#       {
#         "code": "271825005",
#         "display": "Respiratory distress (finding)",
#         "status": "resolved"
#       }
#     ],
#     "total_conditions": 4,
#     "data_quality": {
#       "has_conditions": true,
#       "flag": null
#     }
#   },
#   "procedures": {
#     "clinical_procedures": [
#       {
#         "code": "371908008",
#         "display": "Oxygen administration by mask (procedure)",
#         "occurrence_count": 15
#       },
#       {
#         "code": "431182000",
#         "display": "Placing subject in prone position (procedure)",
#         "occurrence_count": 15
#       },
#       {
#         "code": "399208008",
#         "display": "Plain X-ray of chest (procedure)",
#         "occurrence_count": 1
#       }
#     ],
#     "administrative_procedures": [],
#     "total_procedures": 3,
#     "data_quality": {
#       "high_procedure_count": false,
#       "flag": null
#     }
#   },
#   "medications": {
#     "medications": [
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       },
#       {
#         "code": null,
#         "display": null,
#         "status": "completed"
#       }
#     ],
#     "count": 45,
#     "data_quality": {
#       "has_medications": true,
#       "flag": null
#     }
#   },
#   "observations": {
#     "observations": [
#       {
#         "display": "Respiratory rate",
#         "value": "12.274 /min",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Heart rate",
#         "value": "149.87 /min",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Oxygen saturation in Arterial blood",
#         "value": "78.03 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Body Weight",
#         "value": "77.8 kg",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Leukocytes [#/volume] in Blood by Automated count",
#         "value": "3.4189 10*3/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Erythrocytes [#/volume] in Blood by Automated count",
#         "value": "5.5694 10*6/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Hemoglobin [Mass/volume] in Blood",
#         "value": "11.552 g/dL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Hematocrit [Volume Fraction] of Blood by Automated count",
#         "value": "45.266 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "MCV [Entitic mean volume] in Red Blood Cells by Automated count",
#         "value": "89.755 fL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "MCH [Entitic mass] by Automated count",
#         "value": "28.311 pg",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "MCHC [Entitic Mass/volume] in Red Blood Cells by Automated count",
#         "value": "33.728 g/dL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Erythrocyte [DistWidth] in Blood by Automated count",
#         "value": "13.444 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Platelets [#/volume] in Blood by Automated count",
#         "value": "119.55 10*3/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Neutrophils/Leukocytes in Blood by Automated count",
#         "value": "26.288 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Lymphocytes/Leukocytes in Blood by Automated count",
#         "value": "21.513 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Monocytes/Leukocytes in Blood by Automated count",
#         "value": "12.75 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Eosinophils/Leukocytes in Blood by Automated count",
#         "value": "4.4726 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Basophils/Leukocytes in Blood by Automated count",
#         "value": "3.4109 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Neutrophils [#/volume] in Blood by Automated count",
#         "value": "3.7072 10*3/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Lymphocytes [#/volume] in Blood by Automated count",
#         "value": "1.0258 10*3/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Monocytes [#/volume] in Blood by Automated count",
#         "value": "0.878 10*3/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Eosinophils [#/volume] in Blood by Automated count",
#         "value": "0.42216 10*3/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Basophils [#/volume] in Blood by Automated count",
#         "value": "0.22518 10*3/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Glucose [Mass/volume] in Serum or Plasma",
#         "value": "80.8 mg/dL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Urea nitrogen [Mass/volume] in Serum or Plasma",
#         "value": "7.36 mg/dL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Creatinine [Mass/volume] in Serum or Plasma",
#         "value": "2.5724 mg/dL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Calcium [Mass/volume] in Serum or Plasma",
#         "value": "9.04 mg/dL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Sodium [Moles/volume] in Serum or Plasma",
#         "value": "139.04 mmol/L",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Potassium [Moles/volume] in Serum or Plasma",
#         "value": "4.29 mmol/L",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Body temperature",
#         "value": "41.588 Cel",
#         "date": "2020-08-30"
#       }
#     ],
#     "count": 30
#   },
#   "insurance": {
#     "insurer": "Anthem",
#     "total_cost": 29926.9,
#     "insurance_paid": 23943.9,
#     "patient_responsibility": 5983.0,
#     "requires_prior_auth": true
#   },
#   "metadata": {
#     "assembled_at": "2026-05-13T16:25:30.746186",
#     "encounter_id": "9917e9f0-753a-4673-da3f-ca0de161db03",
#     "data_quality_flags": []
#   }
# }
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)

# %%
#Connection setup (run once at top of every notebook)
import psycopg2
import pandas as pd
import json

conn = psycopg2.connect(dbname="health_ai_portfolio", host="localhost")

def query(sql, params=None):
    return pd.read_sql(sql, conn, params=params)

# %%
df = query("""
    SELECT id, code, display
    FROM medications
    LIMIT 5
""")
df
# Out:
# /var/folders/hq/ytpwb3892fd6ggyxfy3fdhch0000gn/T/ipykernel_27384/2697194343.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, conn, params=params)
#                                      id     code  \
# 0  e7c603f9-2ba8-41a9-13c0-9bf205af943f  1535362
# 1  e89b675a-5d15-5548-b1f4-91544ef52a08  1535362
# 2  906bc99b-54fc-7f02-d951-5d9236c40396  1535362
# 3  ec7b185f-d11f-c561-5ef9-f498e3a197af  1856546
# 4  b36b0667-aaa0-9201-0346-8d8d33628637  1535362
#
#                                              display
# 0              sodium fluoride 0.0272 MG/MG Oral Gel
# 1              sodium fluoride 0.0272 MG/MG Oral Gel
# 2              sodium fluoride 0.0272 MG/MG Oral Gel
# 3  levonorgestrel 0.000729 MG/HR Intrauterine Sys...
# 4              sodium fluoride 0.0272 MG/MG Oral Gel

# %%
df = query("""
    SELECT
        medication_code,
        medication_display,
        status,
        COUNT(*) AS count
    FROM medication_requests
    WHERE encounter_id = '9917e9f0-753a-4673-da3f-ca0de161db03'
    GROUP BY medication_code, medication_display, status
    ORDER BY count DESC
""")
df
# Out:
# /var/folders/hq/ytpwb3892fd6ggyxfy3fdhch0000gn/T/ipykernel_27384/2697194343.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, conn, params=params)
#   medication_code                                 medication_display  \
# 0          198440                   Acetaminophen 500 MG Oral Tablet
# 1         2123111  NDA020503 200 ACTUAT Albuterol 0.09 MG/ACTUAT ...
# 2          854235  0.4 ML Enoxaparin sodium 100 MG/ML Prefilled S...
# 3          854252  1 ML Enoxaparin sodium 150 MG/ML Prefilled Syr...
#
#       status  count
# 0  completed     15
# 1  completed     15
# 2  completed     11
# 3  completed      4

# %%
from importlib import reload
import coding_engine
reload(coding_engine)
from coding_engine import build_encounter_context

context = build_encounter_context(
    '9917e9f0-753a-4673-da3f-ca0de161db03'
)
print(json.dumps(context, indent=2, default=str))
# Out:
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)
# {
#   "encounter": {
#     "encounter_id": "9917e9f0-753a-4673-da3f-ca0de161db03",
#     "patient_id": "9917e9f0-753a-4673-69f1-ca9c42b5669f",
#     "encounter_class": "IMP",
#     "encounter_type": "Hospital admission for isolation (procedure)",
#     "encounter_date": "2020-08-30",
#     "duration_hours": 336.9,
#     "reason": "Disease caused by severe acute respiratory syndrome coronavirus 2 (disorder)",
#     "patient_gender": "female",
#     "patient_age": 28
#   },
#   "conditions": {
#     "diagnoses": [
#       {
#         "code": "233604007",
#         "display": "Pneumonia (disorder)",
#         "status": "resolved"
#       },
#       {
#         "code": "389087006",
#         "display": "Hypoxemia (disorder)",
#         "status": "resolved"
#       },
#       {
#         "code": "271825005",
#         "display": "Respiratory distress (finding)",
#         "status": "resolved"
#       },
#       {
#         "code": "132281000119108",
#         "display": "Acute deep venous thrombosis (disorder)",
#         "status": "resolved"
#       }
#     ],
#     "social_determinants": [],
#     "total_conditions": 4,
#     "data_quality": {
#       "has_conditions": true,
#       "flag": null
#     }
#   },
#   "procedures": {
#     "clinical_procedures": [
#       {
#         "code": "371908008",
#         "display": "Oxygen administration by mask (procedure)",
#         "occurrence_count": 15
#       },
#       {
#         "code": "431182000",
#         "display": "Placing subject in prone position (procedure)",
#         "occurrence_count": 15
#       },
#       {
#         "code": "399208008",
#         "display": "Plain X-ray of chest (procedure)",
#         "occurrence_count": 1
#       }
#     ],
#     "administrative_procedures": [],
#     "total_procedures": 3,
#     "data_quality": {
#       "high_procedure_count": false,
#       "flag": null
#     }
#   },
#   "medications": {
#     "medications": [
#       {
#         "code": "198440",
#         "display": "Acetaminophen 500 MG Oral Tablet",
#         "status": "completed",
#         "occurrence_count": 15
#       },
#       {
#         "code": "2123111",
#         "display": "NDA020503 200 ACTUAT Albuterol 0.09 MG/ACTUAT Metered Dose Inhaler",
#         "status": "completed",
#         "occurrence_count": 15
#       },
#       {
#         "code": "854235",
#         "display": "0.4 ML Enoxaparin sodium 100 MG/ML Prefilled Syringe",
#         "status": "completed",
#         "occurrence_count": 11
#       },
#       {
#         "code": "854252",
#         "display": "1 ML Enoxaparin sodium 150 MG/ML Prefilled Syringe",
#         "status": "completed",
#         "occurrence_count": 4
#       }
#     ],
#     "count": 4,
#     "data_quality": {
#       "has_medications": true,
#       "flag": null
#     }
#   },
#   "observations": {
#     "observations": [
#       {
#         "display": "Respiratory rate",
#         "value": "12.274 /min",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Heart rate",
#         "value": "149.87 /min",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Oxygen saturation in Arterial blood",
#         "value": "78.03 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Body Weight",
#         "value": "77.8 kg",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Leukocytes [#/volume] in Blood by Automated count",
#         "value": "3.4189 10*3/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Erythrocytes [#/volume] in Blood by Automated count",
#         "value": "5.5694 10*6/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Hemoglobin [Mass/volume] in Blood",
#         "value": "11.552 g/dL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Hematocrit [Volume Fraction] of Blood by Automated count",
#         "value": "45.266 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "MCV [Entitic mean volume] in Red Blood Cells by Automated count",
#         "value": "89.755 fL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "MCH [Entitic mass] by Automated count",
#         "value": "28.311 pg",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "MCHC [Entitic Mass/volume] in Red Blood Cells by Automated count",
#         "value": "33.728 g/dL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Erythrocyte [DistWidth] in Blood by Automated count",
#         "value": "13.444 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Platelets [#/volume] in Blood by Automated count",
#         "value": "119.55 10*3/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Neutrophils/Leukocytes in Blood by Automated count",
#         "value": "26.288 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Lymphocytes/Leukocytes in Blood by Automated count",
#         "value": "21.513 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Monocytes/Leukocytes in Blood by Automated count",
#         "value": "12.75 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Eosinophils/Leukocytes in Blood by Automated count",
#         "value": "4.4726 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Basophils/Leukocytes in Blood by Automated count",
#         "value": "3.4109 %",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Neutrophils [#/volume] in Blood by Automated count",
#         "value": "3.7072 10*3/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Lymphocytes [#/volume] in Blood by Automated count",
#         "value": "1.0258 10*3/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Monocytes [#/volume] in Blood by Automated count",
#         "value": "0.878 10*3/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Eosinophils [#/volume] in Blood by Automated count",
#         "value": "0.42216 10*3/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Basophils [#/volume] in Blood by Automated count",
#         "value": "0.22518 10*3/uL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Glucose [Mass/volume] in Serum or Plasma",
#         "value": "80.8 mg/dL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Urea nitrogen [Mass/volume] in Serum or Plasma",
#         "value": "7.36 mg/dL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Creatinine [Mass/volume] in Serum or Plasma",
#         "value": "2.5724 mg/dL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Calcium [Mass/volume] in Serum or Plasma",
#         "value": "9.04 mg/dL",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Sodium [Moles/volume] in Serum or Plasma",
#         "value": "139.04 mmol/L",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Potassium [Moles/volume] in Serum or Plasma",
#         "value": "4.29 mmol/L",
#         "date": "2020-08-30"
#       },
#       {
#         "display": "Body temperature",
#         "value": "41.588 Cel",
#         "date": "2020-08-30"
#       }
#     ],
#     "count": 30
#   },
#   "insurance": {
#     "insurer": "Anthem",
#     "total_cost": 29926.9,
#     "insurance_paid": 23943.9,
#     "patient_responsibility": 5983.0,
#     "requires_prior_auth": true
#   },
#   "metadata": {
#     "assembled_at": "2026-05-13T16:52:53.578002",
#     "encounter_id": "9917e9f0-753a-4673-da3f-ca0de161db03",
#     "data_quality_flags": []
#   }
# }
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)

# %%
from importlib import reload
import coding_engine
reload(coding_engine)
from coding_engine import (
    build_encounter_context,
    suggest_codes
)

# Build context
context = build_encounter_context(
    '9917e9f0-753a-4673-da3f-ca0de161db03'
)

# Call Claude
#suggestions, system_prompt, user_prompt = suggest_codes(context)
user_prompt = suggest_codes(context)


#print(f"system prompt",{system_prompt})
#print(f"-------------------------------------")
#print(f"user prompt",{user_prompt})

# 1. Remove the surrounding curly braces and quotes
# We use .strip() to clean up leading/trailing whitespace and characters
clean_text = user_prompt.strip("{}' ")

# 2. Print it to execute the \n characters
print(clean_text)

# Print cleanly
#print(json.dumps(suggestions, indent=2))
# Out:
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)
# Please review the following encounter and suggest
# appropriate ICD-10-CM and CPT billing codes.
#
# ENCOUNTER SUMMARY
# ────────────────────────────────────────
# Date:              2020-08-30
# Type:              Hospital admission for isolation (procedure)
# Setting:           IMP (Inpatient)
# Duration:          336.9 hours
# Reason for visit:  Disease caused by severe acute respiratory syndrome coronavirus 2 (disorder)
# Patient:           Female, age 28
#
# DIAGNOSES
# ────────────────────────────────────────
#   • Pneumonia (disorder) [existing code: 233604007] (status: resolved)
#   • Hypoxemia (disorder) [existing code: 389087006] (status: resolved)
#   • Respiratory distress (finding) [existing code: 271825005] (status: resolved)
#   • Acute deep venous thrombosis (disorder) [existing code: 132281000119108] (status: resolved)
#
# PROCEDURES PERFORMED
# ────────────────────────────────────────
#   • Oxygen administration by mask (procedure) (×15) [code: 371908008]
#   • Placing subject in prone position (procedure) (×15) [code: 431182000]
#   • Plain X-ray of chest (procedure) [code: 399208008]
#
# MEDICATIONS ORDERED
# ────────────────────────────────────────
#   • Acetaminophen 500 MG Oral Tablet (×15) [RxNorm: 198440]
#   • NDA020503 200 ACTUAT Albuterol 0.09 MG/ACTUAT Metered Dose Inhaler (×15) [RxNorm: 2123111]
#   • 0.4 ML Enoxaparin sodium 100 MG/ML Prefilled Syringe (×11) [RxNorm: 854235]
#   • 1 ML Enoxaparin sodium 150 MG/ML Prefilled Syringe (×4) [RxNorm: 854252]
#
# KEY OBSERVATIONS (vitals & labs)
# ────────────────────────────────────────
#   • Respiratory rate: 12.274 /min
#   • Heart rate: 149.87 /min
#   • Oxygen saturation in Arterial blood: 78.03 %
#   • Body Weight: 77.8 kg
#   • Leukocytes [#/volume] in Blood by Automated count: 3.4189 10*3/uL
#   • Erythrocytes [#/volume] in Blood by Automated count: 5.5694 10*6/uL
#   • Hemoglobin [Mass/volume] in Blood: 11.552 g/dL
#   • Hematocrit [Volume Fraction] of Blood by Automated count: 45.266 %
#   • MCV [Entitic mean volume] in Red Blood Cells by Automated count: 89.755 fL
#   • MCH [Entitic mass] by Automated count: 28.311 pg
#   • MCHC [Entitic Mass/volume] in Red Blood Cells by Automated count: 33.728 g/dL
#   • Erythrocyte [DistWidth] in Blood by Automated count: 13.444 %
#   • Platelets [#/volume] in Blood by Automated count: 119.55 10*3/uL
#   • Neutrophils/Leukocytes in Blood by Automated count: 26.288 %
#   • Lymphocytes/Leukocytes in Blood by Automated count: 21.513 %
#
# INSURANCE
# ────────────────────────────────────────
#   Payer:                Anthem
#   Total cost:           $29,926.90
#   Insurance paid:       $23,943.90
#   Patient responsibility: $5,983.00
#   Prior auth required:  YES
#
# Return your response as a valid JSON object matching
# the structure specified.
# /Users/nilesh/health-ai-portfolio/project1-coding/coding_engine.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn, params=params)

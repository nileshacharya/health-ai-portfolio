# %%
import os
import pandas as pd
import json

print(os.getcwd())
resources = ["Procedures"]
#resources = ["Patients", "Conditions", "Encounters", "Medications"]

for r in resources:
    df = pd.read_csv(f"../data/synthea/output/csv/{r}.csv")
    df.to_json(f"../data/synthea/output/csv/{r}.json", orient="records", lines=False)
# Out:
# /Users/nilesh/health-ai-portfolio/project1-coding

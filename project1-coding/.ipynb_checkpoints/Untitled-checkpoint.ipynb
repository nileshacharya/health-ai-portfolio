# %%
import os
import sys
import json

print(os.getcwd())
os.chdir("/Users/nilesh/health-ai-portfolio/data/synthea/output/fhir")
print(os.getcwd())

# Reading from a file
#with open('Toney527.json', 'r') as file:
#    data = json.load(file)

#print(data)
# Out:
# /Users/nilesh/health-ai-portfolio/data/synthea/output/fhir
# /Users/nilesh/health-ai-portfolio/data/synthea/output/fhir

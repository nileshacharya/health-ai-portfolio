# %%
import os
import sys
import json

print(os.getcwd())
os.chdir("/Users/nilesh/health-ai-portfolio/data/synthea/output/fhir")
print(os.getcwd())

# Reading from a file
with open('Zulma701_Effertz744_d9fa15df-53d7-2f4d-0f73-265a3ef824be.json', 'r') as file:
    data = json.load(file)

print(data)
# Out:
# /Users/nilesh/health-ai-portfolio/data/synthea/output/fhir
# /Users/nilesh/health-ai-portfolio/data/synthea/output/fhir
# ...
